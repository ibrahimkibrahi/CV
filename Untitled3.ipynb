# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrahimkibrahi/CV/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Kaggle & Readding Extenal Data with Pandas

# %%
import pandas as pd
df = pd.read_csv("kaggaleV2_May-2016.csv")
## this show us the first set of data and we can increase this by indicating te nuber in the bracket
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
### the first five rows at the end

df.tail()
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 64726  9.677542e+12        5417381      F  2016-03-01T18:24:24Z
# 64727  4.775398e+14        5671583      F  2016-05-06T19:29:59Z
# 64728  5.952616e+12        5413380      F  2016-03-01T09:33:44Z
# 64729  9.847763e+14        5414803      F  2016-03-01T11:45:39Z
# 64730  3.739783e+12        5417404      F  2016-03-01T18:43:57Z
#
#              AppointmentDay  Age   Neighbourhood  Scholarship  Hipertension  \
# 64726  2016-05-20T00:00:00Z   24  JARDIM CAMBURI            0           0.0
# 64727  2016-05-06T00:00:00Z   29  JARDIM CAMBURI            0           0.0
# 64728  2016-05-06T00:00:00Z   35  JARDIM CAMBURI            0           0.0
# 64729  2016-05-13T00:00:00Z   41  JARDIM CAMBURI            0           0.0
# 64730  2016-05-20T00:00:00Z   38  JARDIM CAMBURI            0           NaN
#
#        Diabetes  Alcoholism  Handcap  SMS_received No-show
# 64726       0.0         0.0      0.0           0.0     Yes
# ...

# %%
df.shape
# Out:
# (110527, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
df.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105270e+05   1.105270e+05  110527.000000  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874       0.098266
# std    2.560949e+14   7.129575e+04      23.110205       0.297675
# min    3.921784e+04   5.030230e+06      -1.000000       0.000000
# 25%    4.172614e+12   5.640286e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680573e+06      37.000000       0.000000
# 75%    9.439172e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.197246       0.071865       0.030400       0.022248
# std         0.397921       0.258265       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
## this show us if they is a missing value
df.isnull()
# Out:
#         PatientId  AppointmentID  Gender  ScheduledDay  AppointmentDay    Age  \
# 0           False          False   False         False           False  False
# 1           False          False   False         False           False  False
# 2           False          False   False         False           False  False
# 3           False          False   False         False           False  False
# 4           False          False   False         False           False  False
# ...           ...            ...     ...           ...             ...    ...
# 110522      False          False   False         False           False  False
# 110523      False          False   False         False           False  False
# 110524      False          False   False         False           False  False
# 110525      False          False   False         False           False  False
# 110526      False          False   False         False           False  False
#
# ...

# %%
### this ask the quwstion if they is a missing value and brings out an output of true or false
df.isna().sum().any()
# Out:
# False

# %%
age = df["Age"]

# %%
age.min()
# Out:
# -1

# %%
age.max()
# Out:
# 115

# %%
df["No-show"]
# Out:
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 110522    No
# 110523    No
# 110524    No
# 110525    No
# 110526    No
# Name: No-show, Length: 110527, dtype: object

# %%
df["No-show"].value_counts()
# Out:
# No     88208
# Yes    22319
# Name: No-show, dtype: int64

# %%
df["No-show"].value_counts(normalize=True)
# Out:
# No     0.798067
# Yes    0.201933
# Name: No-show, dtype: float64

# %%
df["No-show"].value_counts(normalize=True)*100
# Out:
# No     79.806744
# Yes    20.193256
# Name: No-show, dtype: float64

# %%
df["No-show"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='No-show'>

# %%
df["SMS_received"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='SMS_received'>

# %%
df["Gender"].value_counts()
# Out:
# F    41750
# M    22981
# Name: Gender, dtype: int64

# %%
df.groupby(["Gender", "No-show"]).size().reset_index(name="size")
# Out:
#   Gender No-show   size
# 0      F      No  32795
# 1      F     Yes   8954
# 2      M      No  18190
# 3      M     Yes   4791

# %%
import seaborn as sns
sns.countplot(x="Gender", hue = "No-show", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# ## Data Cleaning
#
# Missing values can be handled with Pandas it borrows all the capabilities from NumPy plus a number of convenient methods.

# %% [markdown]
# ### Dectecting Missing values

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay   Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z  62.0    JARDIM DA PENHA          0.0           1.0
# 1  2016-04-29T00:00:00Z  56.0    JARDIM DA PENHA          0.0           0.0
# 2  2016-04-29T00:00:00Z  62.0      MATA DA PRAIA          0.0           0.0
# 3  2016-04-29T00:00:00Z   8.0  PONTAL DE CAMBURI          0.0           0.0
# 4  2016-04-29T00:00:00Z  56.0    JARDIM DA PENHA          0.0           1.0
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0       0.0         0.0      0.0           0.0      No
# ...

# %% [markdown]
# Cheaking for missing values

# %%
df.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    1
# Age               1
# Neighbourhood     1
# Scholarship       1
# Hipertension      1
# Diabetes          1
# Alcoholism        1
# Handcap           1
# SMS_received      1
# No-show           1
# dtype: int64

# %%
import numpy as np
df.isnull().sum().any()
# Out:
# True

# %% [markdown]
# There is no missing value

# %%
df2 = pd.DataFrame({
    'column A': [4, 5, 3, 8],
    'column B': [7,13, np.nan, np.nan],
    'column C': [10, np.nan, 3, np.nan],
    'column D': [12, np.nan, 3, np.nan],
})

# %%
df2.notnull()
# Out:
#    column A  column B  column C  column D
# 0      True      True      True      True
# 1     False      True     False     False
# 2      True     False      True      True
# 3     False     False     False     False

# %%
df2.isnull()
# Out:
#    column A  column B  column C  column D
# 0     False     False     False     False
# 1      True     False      True      True
# 2     False      True     False     False
# 3      True      True      True      True

# %%
df2.isnull().sum().any()
# Out:
# True

# %% [markdown]
# ### Why missing values should be handled

# %%
C = np.array([1,2,np.nan,6,8,np.nan])

# %%
### we will not get the value because we have some missing number and if we do get the number we wont get the actual value because we are having some missing numbers
C.mean()
# Out:
# nan

# %%
C.sum()
# Out:
# nan

# %%
df2
# Out:
#    column A  column B  column C  column D
# 0       4.0       7.0      10.0      12.0
# 1       NaN      13.0       NaN       NaN
# 2       3.0       NaN       3.0       3.0
# 3       NaN       NaN       NaN       NaN

# %%
df2.mean()
# Out:
# column A     3.5
# column B    10.0
# column C     6.5
# column D     7.5
# dtype: float64

# %%
df2.sum()
# Out:
# column A     7.0
# column B    20.0
# column C    13.0
# column D    15.0
# dtype: float64

# %% [markdown]
# ### Drouping the missing values

# %%
#This drops all the rows with the missing values
df2.dropna()
# Out:
#    column A  column B  column C  column D
# 0       4.0       7.0      10.0      12.0

# %%
# when the axis is one it drop the column
df2.dropna(axis=1)
# Out:
#    column A
# 0         4
# 1         5
# 2         3
# 3         8

# %% [markdown]
# ## Filling  the missing values

# %%
df4 = df2.fillna(0)

# %%
df5 = df2.fillna(df2.mean())

# %%
df5
# Out:
#    column A  column B  column C  column D
# 0         4       7.0      10.0      12.0
# 1         5      13.0       6.5       7.5
# 2         3      10.0       3.0       3.0
# 3         8      10.0       6.5       7.5

# %%
df2
# Out:
#    column A  column B  column C  column D
# 0         4       7.0      10.0      12.0
# 1         5      13.0       NaN       NaN
# 2         3       NaN       3.0       3.0
# 3         8       NaN       NaN       NaN

# %%
## This take the value before the missing value and place it in the position of the missing value
df6 = df2.fillna(method="ffill")

# %%
df6
# Out:
#    column A  column B  column C  column D
# 0         4       7.0      10.0      12.0
# 1         5      13.0      10.0      12.0
# 2         3      13.0       3.0       3.0
# 3         8      13.0       3.0       3.0

# %%
## This is the backward fill and it start at the bottom
df7 = df2.fillna(method="bfill")
df7
# Out:
#    column A  column B  column C  column D
# 0         4       7.0      10.0      12.0
# 1         5      13.0       3.0       3.0
# 2         3       NaN       3.0       3.0
# 3         8       NaN       NaN       NaN

# %% [markdown]
# ## Review - Titanic Dataset

# %%
data = pd.read_csv("train.csv")
data.shape
# Out:
# (891, 12)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data[["Name", "Survived"]]
# Out:
#                                                   Name  Survived
# 0                              Braund, Mr. Owen Harris         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                               Heikkinen, Miss. Laina         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4                             Allen, Mr. William Henry         0
# ..                                                 ...       ...
# 886                              Montvila, Rev. Juozas         0
# 887                       Graham, Miss. Margaret Edith         1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0
# 889                              Behr, Mr. Karl Howell         1
# 890                                Dooley, Mr. Patrick         0
#
# [891 rows x 2 columns]

# %%
# we can use iloc to pass in the range o fthe value we want to see and then
data.iloc[1:2, [0,3]]
# Out:
#    PassengerId                                               Name
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...

# %%
data.loc[5]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
data["Age"].min()
# Out:
# 0.42

# %%
data["Age"].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64>

# %%
data["Age"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Clean Your Data with drop(), dropna(), fillna()

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# - filling missing ages

# %%
data["Age"].mean()
# Out:
# 29.69911764705882

# %%
data1 = data.fillna({"Age": data["Age"].mean()})

# %%
data1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.loc[(data.Age.isnull()), "Age"] = 90

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Intressing Idea - Filling the missing values

# %%
## let me pass the minmum of the Age for the value of the missing value in Age if theyis any
data2 = data1.fillna({"Age": data["Age"].min()})

# %%
data2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
data2["Embarked"].values
# Out:
# array(['S', 'C', 'S', 'S', 'S', 'Q', 'S', 'S', 'S', 'C', 'S', 'S', 'S',
#        'S', 'S', 'S', 'Q', 'S', 'S', 'C', 'S', 'S', 'Q', 'S', 'S', 'S',
#        'C', 'S', 'Q', 'S', 'C', 'C', 'Q', 'S', 'C', 'S', 'C', 'S', 'S',
#        'C', 'S', 'S', 'C', 'C', 'Q', 'S', 'Q', 'Q', 'C', 'S', 'S', 'S',
#        'C', 'S', 'C', 'S', 'S', 'C', 'S', 'S', 'C', 0.42, 'S', 'S', 'C',
#        'C', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'C', 'S', 'S', 'S', 'S',
#        'S', 'S', 'S', 'S', 'Q', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S',
#        'S', 'S', 'S', 'S', 'S', 'C', 'C', 'S', 'S', 'S', 'S', 'S', 'S',
#        'S', 'S', 'S', 'S', 'S', 'Q', 'S', 'C', 'S', 'S', 'C', 'S', 'Q',
#        'S', 'C', 'S', 'S', 'S', 'C', 'S', 'S', 'C', 'Q', 'S', 'C', 'S',
#        'C', 'S', 'S', 'S', 'S', 'C', 'S', 'S', 'S', 'C', 'C', 'S', 'S',
#        'Q', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'C',
#        'Q', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S',
# ...

# %%
# this is use to return only the unique values

data2["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', 0.42], dtype=object)

# %%
# 'filling a string
data["Embarked"]= data2["Embarked"].fillna("S")

# %%
data2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
### we can drop the colomn that are not important
data = data.drop({"Cabin", "Fare"}, axis = 1)

# %%
data = data.dropna(axis=0)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Embarked       0
# dtype: int64

# %% [markdown]
# ### Groupy() and value_counts()

# %%
data["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
data["Survived"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='Survived'>

# %%
data["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data.groupby(["Sex"]).mean()
# Out:
# <ipython-input-4-ebbf830c290b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(["Sex"]).mean()
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
data.groupby(["Sex", "Pclass"]).mean()
# Out:
# <ipython-input-5-88b89ada8dd9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(["Sex", "Pclass"]).mean()
#                PassengerId  Survived        Age     SibSp     Parch  \
# Sex    Pclass
# female 1        469.212766  0.968085  34.611765  0.553191  0.457447
#        2        443.105263  0.921053  28.722973  0.486842  0.605263
#        3        399.729167  0.500000  21.750000  0.895833  0.798611
# male   1        455.729508  0.368852  41.281386  0.311475  0.278689
#        2        447.962963  0.157407  30.740707  0.342593  0.222222
#        3        455.515850  0.135447  26.507589  0.498559  0.224784
#
#                      Fare
# Sex    Pclass
# female 1       106.125798
#        2        21.970121
#        3        16.118810
# male   1        67.226127
# ...

# %%
data[data["Age"]< 18]["Pclass"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='Pclass'>

# %%
data.groupby(["Sex", "Survived"]).size().reset_index(name="size")
# Out:
#       Sex  Survived  size
# 0  female         0    81
# 1  female         1   233
# 2    male         0   468
# 3    male         1   109

# %%
import seaborn as sns
sns.countplot(x= "Sex", hue="Survived", data = data)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
plt.style.use("fivethirtyeight")
sns.catplot(x="Pclass", y = "Survived", hue="Sex", data = data, kind="bar")
plt.show()
